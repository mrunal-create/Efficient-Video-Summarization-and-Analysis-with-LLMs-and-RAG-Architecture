# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/examples/multi_modal/multi_modal_video_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Multimodal RAG for processing videos using LLM and LanceDB vectorstore
#
# In this notebook, we showcase a Multimodal RAG architecture designed for video processing. We utilize Gemini Pro Vision and OpenAI GPT4V MultiModal LLM class that employs [CLIP](https://github.com/openai/CLIP) to generate multimodal embeddings. Furthermore, we use [LanceDBVectorStore](https://docs.llamaindex.ai/en/latest/examples/vector_stores/LanceDBIndexDemo.html#) for efficient vector storage.
#
#
#
# Steps:
# 1. Download video from YouTube, process and store it.
#
# 2. Build Multi-Modal index and vector store for both texts and images.
#
# 3. Retrieve relevant images and context, use both to augment the prompt.
#
# 4. Using GPT4V for reasoning the correlations between the input query and augmented data and generating final response.

# %% [markdown]
# ## INSTALL LIBRARIES

# %%
# !pip install llama-index-vector-stores-lancedb
# !pip install llama-index-multi-modal-llms-openai
# !pip install llama-index-multi-modal-llms-openai
# !pip install llama-index-vector-stores-lancedb
# !pip install llama-index-embeddings-clip
# !pip install llama_index ftfy regex tqdm
# !pip install -U openai-whisper
# !pip install git+https://github.com/openai/CLIP.git
# !pip install torch torchvision
# !pip install matplotlib scikit-image
# !pip install lancedb
# !pip install moviepy
# !pip install pytube
# !pip install pydub
# !pip install SpeechRecognition
# !pip install ffmpeg-python
# !pip install soundfile
# !pip install git+https://github.com/openai/CLIP.git
# !pip install llama-index-multi-modal-llms-gemini
# !pip install llama-index-vector-stores-qdrant
# !pip install llama-index-embeddings-gemini
# !pip install llama-index-llms-gemini
# !pip install llama-index 'google-generativeai>=0.3.0' matplotlib qdrant_client
# Out:
# Requirement already satisfied: llama-index-vector-stores-lancedb in c:\users\rainb\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: lancedb<0.6.0,>=0.5.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-vector-stores-lancedb) (0.5.7)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-vector-stores-lancedb) (0.10.18.post1)
# Requirement already satisfied: deprecation in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.9.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (4.66.2)
# Requirement already satisfied: pydantic>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.3.0)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (22.1.0)
# Requirement already satisfied: semver>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (3.0.2)
# Requirement already satisfied: cachetools in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (5.3.2)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (6.0.1)
# Requirement already satisfied: click>=8.1.7 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (8.1.7)
# Requirement already satisfied: requests>=2.31.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.31.0)
# Requirement already satisfied: overrides>=0.7 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (7.7.0)
# Requirement already satisfied: pyarrow>=12 in c:\users\rainb\anaconda3\lib\site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (15.0.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\rainb\anaconda3\lib\site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.24.3)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.26.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.10.0)
# Requirement already satisfied: pandas in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (10.2.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.8.1)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from click>=8.1.7->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.4.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.14.1)
# Requirement already satisfied: anyio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.0.2)
# Requirement already satisfied: idna in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.4)
# Requirement already satisfied: sniffio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rainb\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.14.0)
# Requirement already satisfied: joblib in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2022.7.9)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rainb\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.26.16)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\rainb\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (4.4.2)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\rainb\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rainb\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.20.2)
# Requirement already satisfied: packaging in c:\users\rainb\anaconda3\lib\site-packages (from deprecation->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\rainb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.16.0)
# Requirement already satisfied: llama-index-multi-modal-llms-openai in c:\users\rainb\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-multi-modal-llms-openai) (0.10.18.post1)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-multi-modal-llms-openai) (0.1.7)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.26.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.8.1)
# Requirement already satisfied: numpy in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.24.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.10.0)
# Requirement already satisfied: pandas in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.5.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.8.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.14.1)
# Requirement already satisfied: pydantic>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.3.0)
# Requirement already satisfied: anyio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.5.0)
# Requirement already satisfied: certifi in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.0.2)
# Requirement already satisfied: idna in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.4)
# Requirement already satisfied: sniffio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rainb\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.14.0)
# Requirement already satisfied: click in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2022.7.9)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rainb\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.26.16)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.0.1)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rainb\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2022.7)
# Requirement already satisfied: packaging>=17.0 in c:\users\rainb\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\rainb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.16.0)
# Requirement already satisfied: llama-index-multi-modal-llms-openai in c:\users\rainb\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-multi-modal-llms-openai) (0.10.18.post1)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-multi-modal-llms-openai) (0.1.7)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.26.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.8.1)
# Requirement already satisfied: numpy in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.24.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.10.0)
# Requirement already satisfied: pandas in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.5.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.8.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.14.1)
# Requirement already satisfied: pydantic>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.3.0)
# Requirement already satisfied: anyio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.5.0)
# Requirement already satisfied: certifi in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.0.2)
# Requirement already satisfied: idna in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.4)
# Requirement already satisfied: sniffio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rainb\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.14.0)
# Requirement already satisfied: click in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2022.7.9)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rainb\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.26.16)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.0.1)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rainb\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2022.7)
# Requirement already satisfied: packaging>=17.0 in c:\users\rainb\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (2.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\rainb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-multi-modal-llms-openai) (1.16.0)
# Requirement already satisfied: llama-index-vector-stores-lancedb in c:\users\rainb\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: lancedb<0.6.0,>=0.5.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-vector-stores-lancedb) (0.5.7)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-vector-stores-lancedb) (0.10.18.post1)
# Requirement already satisfied: deprecation in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.9.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (4.66.2)
# Requirement already satisfied: pydantic>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.3.0)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (22.1.0)
# Requirement already satisfied: semver>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (3.0.2)
# Requirement already satisfied: cachetools in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (5.3.2)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (6.0.1)
# Requirement already satisfied: click>=8.1.7 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (8.1.7)
# Requirement already satisfied: requests>=2.31.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.31.0)
# Requirement already satisfied: overrides>=0.7 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (7.7.0)
# Requirement already satisfied: pyarrow>=12 in c:\users\rainb\anaconda3\lib\site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (15.0.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\rainb\anaconda3\lib\site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.24.3)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.26.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.10.0)
# Requirement already satisfied: pandas in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (10.2.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.8.1)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from click>=8.1.7->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.4.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.14.1)
# Requirement already satisfied: anyio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.0.2)
# Requirement already satisfied: idna in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.4)
# Requirement already satisfied: sniffio in c:\users\rainb\anaconda3\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rainb\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.14.0)
# Requirement already satisfied: joblib in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rainb\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2022.7.9)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rainb\anaconda3\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.26.16)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\rainb\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (4.4.2)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\rainb\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (1.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rainb\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (3.20.2)
# Requirement already satisfied: packaging in c:\users\rainb\anaconda3\lib\site-packages (from deprecation->lancedb<0.6.0,>=0.5.1->llama-index-vector-stores-lancedb) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rainb\anaconda3\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\rainb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-lancedb) (1.16.0)
# Requirement already satisfied: llama-index-embeddings-clip in c:\users\rainb\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: ftfy<7.0.0,>=6.1.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-embeddings-clip) (6.1.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-embeddings-clip) (0.10.18.post1)
# Requirement already satisfied: pillow<11.0.0,>=10.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-embeddings-clip) (10.2.0)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-embeddings-clip) (2.2.1)
# Requirement already satisfied: torchvision<0.18.0,>=0.17.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-embeddings-clip) (0.17.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\rainb\anaconda3\lib\site-packages (from ftfy<7.0.0,>=6.1.3->llama-index-embeddings-clip) (0.2.13)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (3.9.3)
# Requirement already satisfied: dataclasses-json in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (2023.10.0)
# Requirement already satisfied: httpx in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (0.26.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (3.8.1)
# Requirement already satisfied: numpy in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (1.24.3)
# Requirement already satisfied: openai>=1.1.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (1.10.0)
# Requirement already satisfied: pandas in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (1.5.3)
# Requirement already satisfied: requests>=2.31.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (0.5.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rainb\anaconda3\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-clip) (4.9.0)
# ...
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rainb\anaconda3\lib\site-packages (from jinja2->torch->openai-whisper) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rainb\anaconda3\lib\site-packages (from sympy->torch->openai-whisper) (1.2.1)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to c:\users\rainb\appdata\local\temp\pip-req-build-z4e0w8y5
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ftfy in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (6.1.3)
# Requirement already satisfied: regex in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (4.66.2)
# Requirement already satisfied: torch in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (2.2.1)
# Requirement already satisfied: torchvision in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (0.17.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\rainb\anaconda3\lib\site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (4.9.0)
# Requirement already satisfied: sympy in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (1.11.1)
# Requirement already satisfied: networkx in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\rainb\anaconda3\lib\site-packages (from torchvision->clip==1.0) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from torchvision->clip==1.0) (10.2.0)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from tqdm->clip==1.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rainb\anaconda3\lib\site-packages (from jinja2->torch->clip==1.0) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rainb\anaconda3\lib\site-packages (from sympy->torch->clip==1.0) (1.2.1)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\Rainb\AppData\Local\Temp\pip-req-build-z4e0w8y5'
# Requirement already satisfied: torch in c:\users\rainb\anaconda3\lib\site-packages (2.2.1)
# Requirement already satisfied: torchvision in c:\users\rainb\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: filelock in c:\users\rainb\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rainb\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\rainb\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\rainb\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\rainb\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\rainb\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\rainb\anaconda3\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rainb\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rainb\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Requirement already satisfied: matplotlib in c:\users\rainb\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: scikit-image in c:\users\rainb\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rainb\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.8 in c:\users\rainb\anaconda3\lib\site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\rainb\anaconda3\lib\site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\rainb\anaconda3\lib\site-packages (from scikit-image) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\rainb\anaconda3\lib\site-packages (from scikit-image) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\rainb\anaconda3\lib\site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\rainb\anaconda3\lib\site-packages (from scikit-image) (0.2)
# Requirement already satisfied: six>=1.5 in c:\users\rainb\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: lancedb in c:\users\rainb\anaconda3\lib\site-packages (0.5.7)
# Requirement already satisfied: deprecation in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (0.9.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (4.66.2)
# Requirement already satisfied: pydantic>=1.10 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (2.3.0)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (22.1.0)
# Requirement already satisfied: semver>=3.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (3.0.2)
# Requirement already satisfied: cachetools in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (5.3.2)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (6.0.1)
# Requirement already satisfied: click>=8.1.7 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (8.1.7)
# Requirement already satisfied: requests>=2.31.0 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (2.31.0)
# Requirement already satisfied: overrides>=0.7 in c:\users\rainb\anaconda3\lib\site-packages (from lancedb) (7.7.0)
# Requirement already satisfied: pyarrow>=12 in c:\users\rainb\anaconda3\lib\site-packages (from pylance==0.9.18->lancedb) (15.0.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\rainb\anaconda3\lib\site-packages (from pylance==0.9.18->lancedb) (1.24.3)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from click>=8.1.7->lancedb) (0.4.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->lancedb) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->lancedb) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\rainb\anaconda3\lib\site-packages (from pydantic>=1.10->lancedb) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.31.0->lancedb) (2023.5.7)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\rainb\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb) (4.4.2)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\rainb\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb) (1.11.0)
# Requirement already satisfied: packaging in c:\users\rainb\anaconda3\lib\site-packages (from deprecation->lancedb) (23.2)
# Requirement already satisfied: moviepy in c:\users\rainb\anaconda3\lib\site-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\rainb\anaconda3\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\rainb\anaconda3\lib\site-packages (from moviepy) (4.66.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\rainb\anaconda3\lib\site-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\rainb\anaconda3\lib\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\rainb\anaconda3\lib\site-packages (from moviepy) (1.24.3)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\rainb\anaconda3\lib\site-packages (from moviepy) (2.26.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\rainb\anaconda3\lib\site-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\rainb\anaconda3\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (10.2.0)
# Requirement already satisfied: setuptools in c:\users\rainb\anaconda3\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (67.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rainb\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rainb\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rainb\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# Requirement already satisfied: pytube in c:\users\rainb\anaconda3\lib\site-packages (15.0.0)
# Requirement already satisfied: pydub in c:\users\rainb\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: SpeechRecognition in c:\users\rainb\anaconda3\lib\site-packages (3.10.1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\rainb\anaconda3\lib\site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\rainb\anaconda3\lib\site-packages (from SpeechRecognition) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rainb\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2023.5.7)
# Requirement already satisfied: ffmpeg-python in c:\users\rainb\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: future in c:\users\rainb\anaconda3\lib\site-packages (from ffmpeg-python) (0.18.3)
# Requirement already satisfied: soundfile in c:\users\rainb\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\rainb\anaconda3\lib\site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\rainb\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to c:\users\rainb\appdata\local\temp\pip-req-build-bmeh5qja
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ftfy in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (6.1.3)
# Requirement already satisfied: regex in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (4.66.2)
# Requirement already satisfied: torch in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (2.2.1)
# Requirement already satisfied: torchvision in c:\users\rainb\anaconda3\lib\site-packages (from clip==1.0) (0.17.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\rainb\anaconda3\lib\site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (4.9.0)
# Requirement already satisfied: sympy in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (1.11.1)
# Requirement already satisfied: networkx in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\rainb\anaconda3\lib\site-packages (from torch->clip==1.0) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\rainb\anaconda3\lib\site-packages (from torchvision->clip==1.0) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\rainb\anaconda3\lib\site-packages (from torchvision->clip==1.0) (10.2.0)
# Requirement already satisfied: colorama in c:\users\rainb\anaconda3\lib\site-packages (from tqdm->clip==1.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rainb\anaconda3\lib\site-packages (from jinja2->torch->clip==1.0) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rainb\anaconda3\lib\site-packages (from sympy->torch->clip==1.0) (1.2.1)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\Rainb\AppData\Local\Temp\pip-req-build-bmeh5qja'

# %% [markdown]
# ## IMPORTS

# %%
from moviepy.editor import VideoFileClip
from pathlib import Path
import speech_recognition as sr
from pytube import YouTube
from pprint import pprint
import os
from llama_index.core.response.notebook_utils import display_source_node
from llama_index.core.schema import ImageNode
from moviepy.editor import VideoFileClip
from pathlib import Path
import speech_recognition as sr
from pytube import YouTube
from pprint import pprint
from llama_index.core.indices import MultiModalVectorStoreIndex
from llama_index.core import SimpleDirectoryReader, StorageContext

from llama_index.core import SimpleDirectoryReader, StorageContext
from llama_index.vector_stores.lancedb import LanceDBVectorStore
from llama_index.core import SimpleDirectoryReader
import os
from llama_index.multi_modal_llms.gemini import GeminiMultiModal

from llama_index.core.multi_modal_llms.generic_utils import load_image_urls
GOOGLE_API_KEY = "AIzaSyDD1M74-7FmtrMAXglgTbMchf3lpedkr3g"  # add your GOOGLE API key here
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
import os

OPENAI_API_TOKEN = "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"
os.environ["OPENAI_API_KEY"] = OPENAI_API_TOKEN

# %% [markdown]
# #### Set configuration for input below

# %%
video_url="https://www.youtube.com/watch?v=d_qvLDhkg00" 
#-- first video link

#video_url = "https://www.youtube.com/watch?v=s7WTQ0H0Acc" 
#-- second video link
output_video_path = "./video_data/"
output_folder = "./mixed_data/"
output_audio_path = "./mixed_data/output_audio.wav"

filepath = output_video_path + "input_vid.mp4"
Path(output_folder).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# #### Download and process videos into appropriate format for generating/storing embeddings

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os


def plot_images(image_paths):
    images_shown = 0
    plt.figure(figsize=(16, 9))
    for img_path in image_paths:
        if os.path.isfile(img_path):
            image = Image.open(img_path)

            plt.subplot(2, 3, images_shown + 1)
            plt.imshow(image)
            plt.xticks([])
            plt.yticks([])

            images_shown += 1
            if images_shown >= 7:
                break

# %%
def download_video(url, output_path):
    """
    Download a video from a given url and save it to the output path.

    Parameters:
    url (str): The url of the video to download.
    output_path (str): The path to save the video to.

    Returns:
    dict: A dictionary containing the metadata of the video.
    """
    yt = YouTube(url)
    metadata = {"Author": yt.author, "Title": yt.title, "Views": yt.views}
    yt.streams.get_highest_resolution().download(
        output_path=output_path, filename="input_vid.mp4"
    )
    return metadata


def video_to_images(video_path, output_folder):
    """
    Convert a video to a sequence of images using VideoFileClip and save them to the output folder.

    Parameters:
    video_path (str): The path to the video file.
    output_folder (str): The path to the folder to save the images to.

    """
    clip = VideoFileClip(video_path)
    clip.write_images_sequence(
        os.path.join(output_folder, "frame%04d.png"), fps=0.2
    )


def video_to_audio(video_path, output_audio_path):
    """
    Convert a video to audio (VideoFileClip ) and save it to the output path.

    Parameters:
    video_path (str): The path to the video file.
    output_audio_path (str): The path to save the audio to.

    """
    clip = VideoFileClip(video_path)
    audio = clip.audio
    audio.write_audiofile(output_audio_path)


def audio_to_text(audio_path):
    """
    Convert audio to text using the SpeechRecognition library.

    Parameters:
    audio_path (str): The path to the audio file.

    Returns:
    test (str): The text recognized from the audio.

    """
    recognizer = sr.Recognizer()
    audio = sr.AudioFile(audio_path)

    with audio as source:
        # Record the audio data
        audio_data = recognizer.record(source)

        try:
            # Recognize the speech
            text = recognizer.recognize_whisper(audio_data)
        except sr.UnknownValueError:
            print("Speech recognition could not understand the audio.")
        except sr.RequestError as e:
            print(f"Could not request results from service; {e}")

    return text

# %%
try:
    metadata_vid = download_video(video_url, output_video_path)
    video_to_images(filepath, output_folder)
    video_to_audio(filepath, output_audio_path)
    text_data = audio_to_text(output_audio_path)

    with open(output_folder + "output_text.txt", "w") as file:
        file.write(text_data)
    print("Text data saved to file")
    file.close()
    os.remove(output_audio_path)
    print("Audio file removed")

except Exception as e:
    raise e
# Out:
# Moviepy - Writing frames ./mixed_data/frame%04d.png.
# Moviepy - Done writing frames ./mixed_data/frame%04d.png.
# MoviePy - Writing audio in ./mixed_data/output_audio.wav
# MoviePy - Done.
# Text data saved to file
# Audio file removed

# %% [markdown]
# ### Create the multi-modal index using LLaMa DB

# %% [markdown]
# ### Multi-Modal Retrieval using GPT text embedding and CLIP image embedding

# %%
text_store = LanceDBVectorStore(uri="lancedb", table_name="text_collection")
image_store = LanceDBVectorStore(uri="lancedb", table_name="image_collection")
storage_context = StorageContext.from_defaults(
    vector_store=text_store, image_store=image_store
)


# Create the MultiModal index
documents = SimpleDirectoryReader(output_folder).load_data()

index = MultiModalVectorStoreIndex.from_documents(
    documents,
    storage_context=storage_context,
)

# %% [markdown]
# #### Use index as retriever to fetch top k (5 in this example) results from the multimodal vector index

# %%
retriever_engine = index.as_retriever(
    similarity_top_k=5, image_similarity_top_k=5
)

# %% [markdown]
# #### Set the RAG  prompt template

# %%
import json

metadata_str = json.dumps(metadata_vid)
#   metadata = {"Author": yt.author, "Title": yt.title, "Views": yt.views}
qa_tmpl_str = (
    "Given the provided information, including relevant images and retrieved context from the video, \
 accurately and precisely answer the query without any additional prior knowledge.\n"
    "Please ensure honesty and responsibility, refraining from any racist or sexist remarks.\n"
    "---------------------\n"
    "Context: {context_str}\n"
    "Metadata for video: {metadata_str} \n"
    "---------------------\n"
    "Query: {query_str}\n"
    "Answer: "
)

# %% [markdown]
# #### Retrieve most similar text/image embeddings baseed on user query from the DB

# %%
def retrieve(retriever_engine, query_str):
    retrieval_results = retriever_engine.retrieve(query_str)

    retrieved_image = []
    retrieved_text = []
    for res_node in retrieval_results:
        if isinstance(res_node.node, ImageNode):
            retrieved_image.append(res_node.node.metadata["file_path"])
        else:
            display_source_node(res_node, source_length=200)
            retrieved_text.append(res_node.text)

    return retrieved_image, retrieved_text

# %% [markdown]
# ## INFERENCE

# %% [markdown]
# #### Add query now, fetch relevant details including images and augment the prompt template

# %% [markdown]
# ### Example 1 : Using video url - https://www.youtube.com/watch?v=d_qvLDhkg00

# %%
query_str = "Using examples from video, explain all things covered in the video regarding the gaussian function"

img, txt = retrieve(retriever_engine=retriever_engine, query_str=query_str)
image_documents = SimpleDirectoryReader(
    input_dir=output_folder, input_files=img
).load_data()   #return top 5 images which can answer the query -
context_str = "".join(txt)
plot_images(img)
# Out:
# **Node ID:** c8574bdc-a9dd-467d-ac1b-8b43fb2a7e75<br>**Similarity:** 0.7427964210510254<br>**Text:** The basic function underlying a normal distribution, aka a Gaussian, is e to the negative x squared. But you might wonder why this function? Of all the expressions we could dream up that give you s...<br>
# **Node ID:** f7cbb038-2bea-4ede-b5bd-b4acfc0a5860<br>**Similarity:** 0.7427964210510254<br>**Text:** The basic function underlying a normal distribution, aka a Gaussian, is e to the negative x squared. But you might wonder why this function? Of all the expressions we could dream up that give you s...<br>
# **Node ID:** 39d0c011-a151-4e23-b996-efe59c601a04<br>**Similarity:** 0.7427964210510254<br>**Text:** The basic function underlying a normal distribution, aka a Gaussian, is e to the negative x squared. But you might wonder why this function? Of all the expressions we could dream up that give you s...<br>
# **Node ID:** d891507b-a55a-4b7f-88e6-9ed6bf437762<br>**Similarity:** 0.7189418077468872<br>**Text:** One common approach to proving this theorem involves two separate steps. The first step is to show that for all the different finite variance distributions you might start with, there exists a sing...<br>
# **Node ID:** 84458910-92c3-4a47-93bd-0b6114965c0e<br>**Similarity:** 0.7189418077468872<br>**Text:** One common approach to proving this theorem involves two separate steps. The first step is to show that for all the different finite variance distributions you might start with, there exists a sing...<br>

# %% [markdown]
# #### Generate final response using GPT4V

# %%
from llama_index.multi_modal_llms.openai import OpenAIMultiModal

openai_mm_llm = OpenAIMultiModal(
    model="gpt-4-vision-preview", api_key=OPENAI_API_TOKEN, max_new_tokens=1500
)

response_1 = openai_mm_llm.complete(
    prompt=qa_tmpl_str.format(
        context_str=context_str, query_str=query_str, metadata_str=metadata_str
    ),
    image_documents=image_documents,
)

pprint(response_1.text)
# Out:
# ('The video titled "A pretty reason why Gaussian + Gaussian = Gaussian" by '
#  '3Blue1Brown covers several aspects of the Gaussian function, also known as '
#  'the normal distribution. Here are the key points discussed in the video:\n'
#  '\n'
#  '1. **Central Limit Theorem**: The video revisits the central limit theorem, '
#  'which states that the sum of multiple copies of a random variable tends to '
#  'form a normal distribution as the number of variables increases, provided '
#  'certain conditions are met.\n'
#  '\n'
#  '2. **Convolution of Random Variables**: The process of adding two random '
#  'variables is explained through the concept of convolution. The video '
#  'describes how to find the distribution of the sum of two random variables by '
#  'computing the convolution of their respective distributions.\n'
#  '\n'
#  '3. **Gaussian Function**: The Gaussian function is more complex than just '
#  '\\( e^{-x^2} \\). The full formula includes a normalization factor and '
#  'parameters for the mean (\\( \\mu \\)) and standard deviation (\\( \\sigma '
#  '\\)). The standard form of the Gaussian function is given by:\n'
#  '   \\[\n'
#  '   \\frac{1}{\\sigma\\sqrt{2\\pi}} '
#  'e^{-\\frac{1}{2}\\left(\\frac{x-\\mu}{\\sigma}\\right)^2}\n'
#  '   \\]\n'
#  '   This ensures that the area under the curve is 1, making it a valid '
#  'probability distribution.\n'
#  '\n'
#  '4. **Adding Two Gaussian Distributions**: The video explores what happens '
#  'when two normally distributed random variables are added together. This is '
#  'equivalent to computing the convolution of two Gaussian functions.\n'
#  '\n'
#  '5. **Visual Intuition and Geometric Argument**: Instead of just using '
#  'algebraic manipulation, the video presents a visual and geometric argument '
#  'for understanding the convolution of two Gaussian functions. This involves '
#  'looking at diagonal slices on the xy-plane and leveraging the rotational '
#  'symmetry of the graph.\n'
#  '\n'
#  '6. **Fixed Point of Convolution**: It is shown that the convolution of two '
#  'Gaussians results in another Gaussian. This property means that a Gaussian '
#  'distribution is a fixed point under convolution, which is a key step in '
#  'proving the central limit theorem.\n'
#  '\n'
#  '7. **Connection to Pi and Entropy**: The video discusses how the geometric '
#  'argument connects to the presence of pi in the Gaussian formula and touches '
#  'on an alternative approach to understanding Gaussians using entropy.\n'
#  '\n'
#  '8. **Engagement with the Audience**: The creator encourages viewers to stay '
#  'informed about new videos and projects through a mailing list and mentions '
#  'contributions from the community, such as insights from a channel supporter, '
#  'Dr. Vide Quinter.\n'
#  '\n'
#  'Throughout the video, the author provides a deep dive into the mathematical '
#  'properties of the Gaussian function and its significance in probability '
#  'theory, particularly in relation to the central limit theorem. The video '
#  'uses visual examples and animations to help viewers grasp the concepts more '
#  'intuitively.')

# %% [markdown]
# #### Generate final response using GEMINI PRO VISION LLM

# %%
gemini_pro = GeminiMultiModal(model_name="models/gemini-pro-vision")
response_1 = gemini_pro.complete(
    prompt=qa_tmpl_str.format(
        context_str=context_str, query_str=query_str, metadata_str=metadata_str
    ),
    image_documents=image_documents,
)
pprint(response_1.text)
# Out:
# (' - The video starts by introducing the Gaussian function, which is a type of '
#  'probability distribution. \n'
#  '- It is defined by the equation $$f(x) = \\frac{1}{\\sigma '
#  '\\sqrt{2\\pi}}e^{-\\frac{(x-\\mu)^2}{2\\sigma^2}}$$\n'
#  '- The graph of a Gaussian function is a bell-shaped curve. \n'
#  '- The mean of the distribution is \\(\\mu\\) and the standard deviation is '
#  '\\(\\sigma\\). \n'
#  '- The video then discusses the central limit theorem, which states that the '
#  'sum of a large number of independent random variables will have a Gaussian '
#  'distribution. \n'
#  '- This is because the sum of a large number of independent random variables '
#  'will have a mean that is equal to the sum of the means of the individual '
#  'random variables, and a variance that is equal to the sum of the variances '
#  'of the individual random variables. \n'
#  '- The video then shows how the central limit theorem can be used to explain '
#  'the shape of the Gaussian distribution. \n'
#  '- It also discusses some of the properties of the Gaussian distribution, '
#  'such as the fact that it is a unimodal distribution and that it is symmetric '
#  'about its mean. \n'
#  '- Finally, the video discusses some of the applications of the Gaussian '
#  'distribution, such as in statistics and in physics.')

# %% [markdown]
# ### Example 2 - Using video url - https://www.youtube.com/watch?v=s7WTQ0H0Acc

# %%
# Below code is for video url 2  -- change in configuration settings above

# %%
# query_str = "Using examples from video, explain all things covered in the video regarding the variance"

# img, txt = retrieve(retriever_engine=retriever_engine, query_str=query_str)
# image_documents = SimpleDirectoryReader(
#     input_dir=output_folder, input_files=img
# ).load_data()
# context_str = "".join(txt)
# plot_images(img)

# %% [markdown]
# #### Generate final response using GPT4V

# %%
# from llama_index.multi_modal_llms.openai import OpenAIMultiModal

# openai_mm_llm = OpenAIMultiModal(
#     model="gpt-4-vision-preview", api_key=OPENAI_API_TOKEN, max_new_tokens=1500
# )


# response_1 = openai_mm_llm.complete(
#     prompt=qa_tmpl_str.format(
#         context_str=context_str, query_str=query_str, metadata_str=metadata_str
#     ),
#     image_documents=image_documents,
# )

# pprint(response_1.text)
